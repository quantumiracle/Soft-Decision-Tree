# %% [markdown]
# # Test with MNIST

# %%
import torch
import torch.nn as nn
import numpy as np
import tensorflow as tf

mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_test.shape)
# Out:
# /home/quantumiracle/.conda/envs/robo/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/quantumiracle/.conda/envs/robo/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/quantumiracle/.conda/envs/robo/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
import matplotlib.pyplot as plt

one_img=x_test[0]
print(one_img.shape)
plt.imshow(one_img)
plt.show()
# Out:
# (28, 28)

# %%
def imgs_diff(img1, img2, scale=255., reduction='mean'):
    loss = nn.MSELoss(reduction=reduction)
    output = loss(img1, img2)
    return output/ (scale**2)

# %%
import torch.nn.functional as F

nb_channels = 1
h, w = 5, 5
x=torch.tensor(one_img).view(1,nb_channels,one_img.shape[0], one_img.shape[1]).float()
print('Input shape: ',x.shape)
# x = torch.randn(1, nb_channels, , w)
weights = torch.tensor([[0.5, 0., 0.2],
                        [0., 1., 0.],
                        [-0.2, 0., -0.5]])
weights = weights.view(1, 1, 3, 3).repeat(1, nb_channels, 1, 1)

output = F.conv2d(x, weights, padding=1)  # no size reduction
print('Output shape: ', output.shape)
plt.imshow(output.squeeze())
plt.show()
print('Difference from original: ', imgs_diff(x, output))
print('Difference from original: ', imgs_diff(x, x))
# Out:
# Input shape:  torch.Size([1, 1, 28, 28])
# Output shape:  torch.Size([1, 1, 28, 28])
# Difference from original:  tensor(0.0371)
# Difference from original:  tensor(0.)

# %%
# another round of convolution
weights = torch.tensor([[-0.5, 0.1, -0.2],
                        [0.3, -2., 0.],
                        [0.1, 0.2, 0]])
weights = weights.view(1, 1, 3, 3).repeat(1, nb_channels, 1, 1)

weights = torch.tensor([[-0.5, 0.1],
                        [0.3, -2.]])
weights = weights.view(1, 1, 3, 3).repeat(1, nb_channels, 1, 1)
output = F.conv2d(output, weights, padding=1)
print('Output shape: ', output.shape)
plt.imshow(output.squeeze())
plt.show()
print('Difference from original: ', imgs_diff(x, output))
# Out:
# Output shape:  torch.Size([1, 1, 28, 28])
# Difference from original:  tensor(0.7369)

# %%
mask = torch.abs(torch.randn(x.shape))
masked_output = mask*output
plt.imshow(masked_output.squeeze())
plt.show()
print('Difference from original: ', imgs_diff(x, masked_output))
# Out:
# Difference from original:  tensor(0.6260)

# %%
import torch.nn.functional as F
from torch.nn.parameter import Parameter

class SpatialSoftmax(torch.nn.Module):
    def __init__(self, height, width, channel, temperature=None, data_format='NCHW'):
        super(SpatialSoftmax, self).__init__()
        self.data_format = data_format
        self.height = height
        self.width = width
        self.channel = channel

        if temperature:
            self.temperature = Parameter(torch.ones(1)*temperature)
        else:
            self.temperature = 1.

        pos_x, pos_y = np.meshgrid(
                np.linspace(-1., 1., self.height),
                np.linspace(-1., 1., self.width)
                )
        pos_x = torch.from_numpy(pos_x.reshape(self.height*self.width)).float()
        pos_y = torch.from_numpy(pos_y.reshape(self.height*self.width)).float()
        self.register_buffer('pos_x', pos_x)
        self.register_buffer('pos_y', pos_y)

    def forward(self, feature):
        # Output:
        #   (N, C*2) x_0 y_0 ...
        if self.data_format == 'NHWC':
            feature = feature.transpose(1, 3).tranpose(2, 3).view(-1, self.height*self.width)
        else:
            feature = feature.view(-1, self.height*self.width)

        softmax_attention = F.softmax(feature/self.temperature, dim=-1)
        expected_x = torch.sum(self.pos_x*softmax_attention, dim=1, keepdim=True)
        expected_y = torch.sum(self.pos_y*softmax_attention, dim=1, keepdim=True)
        expected_xy = torch.cat([expected_x, expected_y], 1)
        feature_keypoints = expected_xy.view(-1, self.channel*2)

        return feature_keypoints
    
ssm = SpatialSoftmax(28,28,1,temperature=1.)
keypoint = ssm(x)
print(keypoint)
plt.imshow(x.squeeze())
[x,y]=keypoint.detach().cpu().numpy()[0]
plt.scatter(14*(x+1),14*(y+1), color='r')
plt.show()
# Out:
# tensor([[0.0605, 0.1440]], grad_fn=<ViewBackward>)

# %%
y=torch.tensor(x_test[:2]).view(2,1,28, 28).float()
d=imgs_diff(y, masked_output, reduction='none')
d.view(d.shape[0], -1).mean(-1)
# Out:
# tensor([0.1679, 0.2616])

# %%
a=torch.tensor([[1,0,1],[0,1,0]])
b=torch.tensor([[1,2,3]])
print(a.shape, b.shape)
c=torch.einsum('ij,kj->ikj', a, b)
print(c.shape,c)
# Out:
# torch.Size([2, 3]) torch.Size([1, 3])
# torch.Size([2, 1, 3]) tensor([[[1, 0, 3]],
#
#         [[0, 2, 0]]])

# %% [markdown]
# ## Plot decision process for single instance

# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_test.shape)
# Out:
# /home/quantumiracle/.conda/envs/robo/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/quantumiracle/.conda/envs/robo/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/quantumiracle/.conda/envs/robo/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
input_img = x_test[90]

draw_tree(tree, 28, 28, 1, input_img=input_img)

# %% [markdown]
# ## SDT for State-Action Data

# %%
import torch
import torch.nn as nn
from SDT import SDT
from torch.utils import data
from utils.dataset import Dataset
import numpy as np
from sdt_train import learner_args, test_tree
from tree_plot import draw_tree

tree = SDT(learner_args)
tree.load_model(learner_args['model_path'])
test_tree(tree, epochs=1)

draw_tree(tree, (tree.args['input_dim'],))
# Out:
# /home/quantumiracle/.conda/envs/robo/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/quantumiracle/.conda/envs/robo/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/quantumiracle/.conda/envs/robo/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
x = np.load('./data/discrete_state.npy')
print(x[20])
draw_tree(tree, (tree.args['input_dim'],), input_img=x[20])
# Out:
# [-0.12245779  1.3709819  -0.56040555 -0.35119036 -0.11945684 -0.18088013
#   0.          0.        ]

# %%
import torch
import torch.nn as nn
from SDT import SDT
from torch.utils import data
from utils.dataset import Dataset
import numpy as np
from sdt_train import learner_args, test_tree
from tree_plot import draw_tree

tree = SDT(learner_args)
learner_args['depth']=3
tree.load_model(learner_args['model_path'])
test_tree(tree, epochs=1)

draw_tree(tree, (tree.args['input_dim'],))
# Out:
# /home/quantumiracle/.conda/envs/robo/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/quantumiracle/.conda/envs/robo/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/quantumiracle/.conda/envs/robo/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
import numpy as np
import torch

def cross_entropy(predictions, targets, epsilon=1e-12):
    """
    Computes cross entropy between targets (encoded as one-hot vectors)
    and predictions. 
    Input: predictions (N, k) ndarray
           targets (N, k) ndarray        
    Returns: scalar
    """
    predictions = np.clip(predictions, epsilon, 1. - epsilon)
    N = predictions.shape[0]
    ce = -np.sum(targets*np.log(predictions+1e-9))/N
    return ce

tar=np.array([[0.5, 0.5]])
p1=np.array([[1,0]])
p2=np.array([[0.5,0.5]])
p3=np.array([[0.49,0.51]])
print(cross_entropy(p1, tar), cross_entropy(p2, tar),  cross_entropy(p3, tar))
# Out:
# 10.361133167807164 0.6931471785599453 0.6933472185698148

# %%
import numpy as np

a=np.ones((2,3,4))
b=a
np.multiply(a,b).shape
# Out:
# (2, 3, 4)
